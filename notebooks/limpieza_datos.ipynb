# %% [markdown]
# # Taller: Limpieza y Normalización de Datos con Python
#
# ## Doctorado en Ingeniería
# Universidad Distrital Francisco José de Caldas
#
# ---
#
# ## Objetivo
#
# Desarrollar habilidades para:
#
# - Identificar problemas de calidad de datos
# - Limpiar datasets reales
# - Aplicar técnicas de normalización
# - Preparar datos para análisis y modelado
#
# ---
#
# ## Tecnologías utilizadas
#
# - Python
# - Pandas
# - NumPy
# - Jupyter Notebook
# - Git y GitHub

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Carga y exploración del dataset
#
# En esta sección cargaremos el dataset académico y realizaremos una inspección inicial de la información.

# %%
df = pd.read_csv("../data/raw/solicitudes_robusto.csv")
