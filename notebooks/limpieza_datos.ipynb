# %% [markdown]
# # Taller: Limpieza, Transformación y Normalización de Datos con Python
#
# ## Doctorado en Ingeniería
# ### Universidad Distrital Francisco José de Caldas
#
# ---
#
# ## Objetivo del taller
#
# Desarrollar competencias prácticas en limpieza, validación, transformación y normalización de datos utilizando Python y herramientas modernas de análisis de datos.
#
# ---
#
# ## Herramientas utilizadas
#
# - Python
# - Pandas
# - NumPy
# - Jupyter Notebook
# - Git
# - GitHub
# - VS Code
#
# ---
#
# ## Metodología
#
# El taller se desarrollará mediante:
#
# - explicación teórica
# - demostraciones guiadas
# - ejercicios prácticos
# - resolución de problemas
# - trabajo con datasets reales

# %% [markdown]
# # Módulo 0 — Introducción a ETL y calidad de datos

# %% [markdown]
# ## ¿Qué es ETL?
#
# ETL significa:
#
# | Fase | Descripción |
# |---|---|
# | Extract | extracción de datos |
# | Transform | transformación y limpieza |
# | Load | carga o exportación |
#
# ---
#
# ## Flujo ETL del taller
#
# ```text
# CSV sucio
# ↓
# Python + Pandas
# ↓
# Transformaciones
# ↓
# Dataset limpio
# ↓
# Exportación

# %% [markdown]
# ## Importancia de la calidad de datos
#
# Los datos son el principal insumo en:
#
# - analítica de datos
# - inteligencia artificial
# - investigación científica
# - automatización
# - visualización de información
#
# ---
#
# ### ¿Por qué es importante limpiar los datos?
#
# Los datasets reales normalmente contienen:
#
# - errores humanos
# - datos faltantes
# - registros duplicados
# - inconsistencias
# - formatos incorrectos
#
# Si los datos no son tratados adecuadamente, los resultados obtenidos pueden ser incorrectos o poco confiables.
#
# ---
#
# ## Ejemplos de problemas reales
#
# ### Valores nulos
#
# ```text
# edad = NaN
# correo = vacío
# ```
#
# ---
#
# ### Inconsistencias de texto
#
# ```text
# Bogotá
# bogota
# BOGOTA
# Bogota
# ```
#
# ---
#
# ### Outliers
#
# ```text
# edad = 120
# promedio = 9.5
# ```
#
# ---
#
# ### Tipos de datos incorrectos
#
# ```text
# promedio = cuatro
# valor_pagado = cincuenta mil
# ```
#
# ---
#
# ### Duplicados
#
# ```text
# mismo estudiante registrado varias veces
# ```

# %% [markdown]
# # Ejercicio guiado — Identificación de problemas
#
# # Analice el siguiente dataset:
#
# | nombre | edad | ciudad | promedio |
# |---|---|---|---|
# | Juan | 25 | Bogotá | 4.5 |
# | Maria | NaN | bogota | 3.8 |
# | Carlos | ciento veinte | BOGOTA | cuatro |
# | Juan | 25 | Bogotá | 4.5 |
#
# ---
#
# ## Preguntas
#
# - ¿Qué problemas identifica?
# - ¿Qué columnas presentan inconsistencias?
# - ¿Existen registros duplicados?
# - ¿Qué valores parecen incorrectos?
# - ¿Qué impacto tendrían estos errores en un análisis?

# %% [markdown]
# # Conceptos clave del módulo
#
# ## Calidad de datos
#
# Hace referencia al nivel de confiabilidad, precisión y consistencia de un dataset.
#
# ---
#
# ## ETL
#
# Proceso utilizado para:
#
# 1. Extraer datos
# 2. Transformar y limpiar información
# 3. Cargar o exportar resultados
#
# ---
#
# ## Transformación de datos
#
# Consiste en modificar la información para:
#
# - corregir errores
# - estandarizar formatos
# - preparar análisis
# - automatizar procesos
#
# ---
#
# ## Reproducibilidad
#
# Capacidad de repetir un proceso y obtener el mismo resultado utilizando los mismos datos y scripts.

# %% [markdown]
# # Conclusión del módulo
#
# La calidad de los datos es uno de los aspectos más importantes en cualquier proyecto de análisis, investigación o inteligencia artificial.
#
# Un dataset incorrecto puede producir:
#
# - análisis erróneos
# - modelos sesgados
# - decisiones incorrectas
# - resultados inconsistentes
#
# Por esta razón, la limpieza y transformación de datos es una etapa fundamental dentro de cualquier flujo moderno de ingeniería y ciencia de datos.

# %% [markdown]
# # Módulo 1 — Preparación del entorno y arquitectura del proyecto

# %% [markdown]
# ## Objetivos del módulo
#
# Al finalizar este módulo el participante podrá:
#
# - Comprender la estructura del proyecto
# - Instalar las dependencias necesarias
# - Utilizar Git y GitHub para versionamiento
# - Ejecutar notebooks con Jupyter
# - Trabajar con entornos reproducibles

# %% [markdown]
# # Herramientas utilizadas
#
# | Herramienta | Función |
# |---|---|
# | Python | Lenguaje principal |
# | Pandas | Manipulación de datos y análisis tabular |
# | NumPy | Operaciones numéricas |
# | Jupyter Notebook | Entorno interactivo |
# | VS Code | Editor de código |
# | Git | Control de versiones |
# | GitHub | Repositorio remoto |

# %% [markdown]
# # ¿Por qué utilizar Git y GitHub?
#
# Git permite:
#
# - Controlar versiones
# - Recuperar cambios
# - Trabajar colaborativamente
# - Mantener trazabilidad del proyecto
#
# GitHub permite:
#
# - Almacenar repositorios remotos
# - Compartir proyectos
# - Documentar procesos
# - Mantener respaldo del código

# %% [markdown]
# # Flujo de trabajo profesional
#
# ```text
# GitHub
# ↓
# git clone
# ↓
# trabajo local
# ↓
# modificaciones
# ↓
# git add
# ↓
# git commit
# ↓
# git push
# ↓
# actualización del repositorio
# ```

# %% [markdown]
# # Estructura del proyecto
#
# ```text
# Taller-limpieza-datos-python/
# │
# ├── data/
# │   ├── raw/
# │   └── processed/
# │
# ├── notebooks/
# │
# ├── outputs/
# │
# ├── src/
# │
# ├── requirements.txt
# ├── README.md
# └── .gitignore
# ```

# %% [markdown]
# # Descripción de carpetas
#
# | Carpeta | Función |
# |---|---|
# | data/raw | datasets originales |
# | data/processed | datasets limpios |
# | notebooks | notebooks del taller |
# | outputs | reportes y resultados |
# | src | scripts Python |

# %% [markdown]
# # Instalación del proyecto
#
# ## Clonar repositorio
#
# ```bash
# git clone https://github.com/DoctoradoIngUD/Taller-limpieza-datos-python.git
# ```
#
# ---
#
# ## Ingresar al proyecto
#
# ```bash
# cd Taller-limpieza-datos-python
# ```
#
# ---
#
# ## Instalar dependencias
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ---
#
# ## Ejecutar Jupyter Notebook
#
# ```bash
# jupyter notebook
# ```

# %% [markdown]
# # Archivo requirements.txt
#
# El archivo `requirements.txt` contiene las librerías necesarias para ejecutar el proyecto.
#
# Esto permite:
#
# - reproducibilidad
# - compatibilidad
# - instalación rápida
# - estandarización del entorno

# %% [markdown]
# # Librerías principales del taller
#
# | Librería | Uso |
# |---|---|
# | pandas | Manipulación de datos |
# | numpy | Cálculos numéricos |
# | matplotlib | Gráficos de línea, barra, dispersión -Visualización |
# | seaborn |Análisis gráfico - Visualización avanzada |

# %% [markdown]
# # Introducción a Jupyter Notebook
#
# Jupyter Notebook es un entorno interactivo que permite:
#
# - Combinar teoría y código
# - Ejecutar Python por bloques
# - Documentar análisis
# - Visualizar resultados en tiempo real
#
# ---
#
# ## Ventajas
#
# - Permite un aprendizaje interactivo
# - La visualización es inmediata
# - Es ideal para ciencia de datos y excelente para investigación académica

# %% [markdown]
# # Tipos de celdas en Jupyter
#
# | Tipo | Función |
# |---|---|
# | Markdown | documentación |
# | Code | ejecución de Python |
# | Raw | texto sin formato |

# %% [markdown]
# # Reproducibilidad en ciencia de datos
#
# Un proyecto reproducible permite:
#
# - Repetir experimentos
# - Validar resultados
# - Compartir análisis
# - Facilitar auditorías
# - Garantizar transparencia

# %% [markdown]
# # Ejercicio guiado
#
# ## Preguntas
#
# - ¿Cuál es la función de Git?
# - ¿Por qué usar GitHub?
# - ¿Qué ventajas ofrece Jupyter Notebook?
# - ¿Por qué separar datos raw y processed?
# - ¿Qué significa reproducibilidad?

# %% [markdown]
# # Conclusión del módulo
#
# El uso de herramientas modernas permite construir proyectos de datos escalables y profesionales.
# La preparación adecuada del entorno garantiza:
# Estabilidad, organización y trazabilidad

# %% [markdown]
# # Módulo 2 — Introducción a Pandas, Numpy y exploración de datos

# %% [markdown]
# ## Objetivos del módulo
#
# Al finalizar este módulo el participante podrá:
#
# - Importar librerías en Python
# - Cargar datasets CSV
# - Trabajar con DataFrames
# - Explorar información
# - Identificar estructura y tipos de datos
# - Realizar análisis exploratorio inicial

# %% [markdown]
# # ¿Qué es Pandas?
#
# Pandas es una librería de Python especializada en:
#
# - Manipulación de datos
# - Análisis tabular
# - Limpieza de información
# - Transformación de datasets
#
# ---
#
# ## Estructuras principales
#
# | Estructura | Descripción |
# |---|---|
# | Series | columna unidimensional |
# | DataFrame | tabla bidimensional |

# %% [markdown]
# ## ¿Qué es NumPy?
#
# NumPy es una librería de Python especializada en:
#
# - Cálculos matemáticos y estadísticos
# - Computación numérica
# - Operaciones matemáticas avanzadas
# - Manejo eficiente de arreglos multidimensionales
# - Procesamiento científico y estadístico de datos
#
# ---
#
# ## Estructuras principales
#
# | Estructura | Descripción |
# |---|---|
# | ndarray | arreglo multidimensional optimizado |
# | array | estructura principal para cálculos numéricos |
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Carga del dataset principal
#
# El dataset contiene información simulada de solicitudes académicas y administrativas.
#
# El objetivo será:
#
# - Identificar problemas
# - Limpiar información
# - Transformar datos
# - Generar datasets consistentes

# %%
df = pd.read_csv('../data/raw/solicitudes_robusto.csv')

# %% [markdown]
# # Visualización inicial del dataset
#
# La función `head()` permite visualizar los primeros registros del DataFrame. Es útil para comprobar rápidamente si el objeto contiene el tipo de datos correcto. Si usamos la función sin especificar un número de filas, nos traerá los primeros 5 registros, pero si queremos un numero especifico de filas para mostrar debemos dejar el número dentro de los parentesis EJ: .head(7)

# %%
df.head()
# Out:
#    id_solicitud  codigo_estudiante  documento       nombre_estudiante  \
# 0             1          202453165   33996128   María Galvis Calderón
# 1             2          202471329   59188252  Mercedes Riascos Muñoz
# 2             3          202477124   37731834    Diana Cano Caballero
# 3             4          202461124   84034125      Rosa Vanegas Arias
# 4             5          202426793   86508604   Claudia Agudelo Arias
#
#                  programa              facultad semestre promedio  \
# 0  Maestría en Ingeniería  Ciencias y Educación        9     4.56
# 1  Ingeniería de Sistemas  Ciencias y Educación        5     3.47
# 2  Maestría en Ingeniería  Ciencias y Educación       11      NaN
# 3   Ingeniería Industrial  Ciencias y Educación        5     3.06
# 4  Ingeniería Electrónica  Ciencias y Educación        3     3.96
#
#   creditos_aprobados tipo_solicitud fecha_solicitud estado_solicitud  \
# 0                 46   Homologación      2025-07-23       En proceso
# ...

# %% [markdown]
# # Dimensiones del dataset
#
# La función `shape` permite identificar número de filas y número de columnas.
# Debido a la información que proporciona lo convierte en un método más informativo para comprender el tamaño del conjunto de datos, devuelve una tupla con las dimensiones del DataFrame

# %%
df.shape
# Out:
# (510, 19)

# %% [markdown]
# # Información general del DataFrame
#
# La función `info()` permite visualizar:
#
# - Nombres de columnas
# - Tipos de datos
# - Cantidad de valores no nulos
# - Uso de memoria

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_solicitud        510 non-null    int64
#  1   codigo_estudiante   510 non-null    int64
#  2   documento           510 non-null    int64
#  3   nombre_estudiante   510 non-null    str
#  4   programa            510 non-null    str
#  5   facultad            510 non-null    str
#  6   semestre            510 non-null    str
#  7   promedio            484 non-null    str
#  8   creditos_aprobados  510 non-null    str
#  9   tipo_solicitud      510 non-null    str
#  10  fecha_solicitud     510 non-null    str
#  11  estado_solicitud    510 non-null    str
#  12  valor_pagado        510 non-null    str
#  13  correo              485 non-null    str
#  14  telefono            485 non-null    str
#  15  ciudad              510 non-null    str
# ...

# %% [markdown]
# # Descripción estadística
#
# La función `describe()` calcula estadísticas descriptivas básicas para variables numéricas. El resultado variará según los datos proporcionados

# %%
df.describe()
# Out:
#        id_solicitud  codigo_estudiante     documento
# count    510.000000       5.100000e+02  5.100000e+02
# mean     250.741176       2.024550e+08  5.443032e+07
# std      144.531408       2.561558e+04  2.548392e+07
# min        1.000000       2.024101e+08  1.016124e+07
# 25%      126.250000       2.024328e+08  3.303767e+07
# 50%      250.500000       2.024551e+08  5.367107e+07
# 75%      374.750000       2.024771e+08  7.643679e+07
# max      500.000000       2.025000e+08  9.961005e+07

# %% [markdown]
# # Visualización de columnas
#
# La propiedad `columns` permite identificar las variables disponibles en el dataset. almacenando los nombres de las columnas como un objeto en Pandas que podrá ser utilizado para cambio de nombre, alineación y seleción de datos.

# %%
df.columns
# Out:
# Index(['id_solicitud', 'codigo_estudiante', 'documento', 'nombre_estudiante',
#        'programa', 'facultad', 'semestre', 'promedio', 'creditos_aprobados',
#        'tipo_solicitud', 'fecha_solicitud', 'estado_solicitud', 'valor_pagado',
#        'correo', 'telefono', 'ciudad', 'modalidad', 'edad', 'observaciones'],
#       dtype='str')

# %% [markdown]
# # Tipos de datos
#
# La propiedad `dtypes` permite identificar el tipo de cada columna. La serie que arroja, contiene la primera columna correspondiente a los nombres originales del DataFrame y la segunda especifica el tipo de datos, los cuales pueden ser:
#
#
# | Tipos de datos | Descripción |
# |---|---|
# | str | Cadena de texto |
# | int64 | Números enteros |
# | bool | Verdadero / Falso |
# | float64 | Números con decimales |
#
# ---

# %%
df.dtypes
# Out:
# id_solicitud          int64
# codigo_estudiante     int64
# documento             int64
# nombre_estudiante       str
# programa                str
# facultad                str
# semestre                str
# promedio                str
# creditos_aprobados      str
# tipo_solicitud          str
# fecha_solicitud         str
# estado_solicitud        str
# valor_pagado            str
# correo                  str
# telefono                str
# ciudad                  str
# modalidad               str
# edad                    str
# observaciones           str
# dtype: object

# %% [markdown]
# # Selección de columnas
#
# Es posible seleccionar columnas específicas dentro del DataFrame.

# %%
df[['nombre_estudiante', 'edad', 'ciudad']].head()
# Out:
#         nombre_estudiante  edad       ciudad
# 0   María Galvis Calderón  34.0     Medellín
# 1  Mercedes Riascos Muñoz  33.0      Bogota
# 2    Diana Cano Caballero  25.0     Medellín
# 3      Rosa Vanegas Arias  25.0     Medellín
# 4   Claudia Agudelo Arias  44.0  Bucaramanga

# %% [markdown]
# # Filtrado de registros
#
# Pandas permite filtrar información utilizando condiciones.

# %% [markdown]
# # Problema de tipos de datos
#
# En datasets reales es común encontrar columnas numéricas con valores incorrectos:
#
# ```text
# 25
# 30
# treinta
# ciento veinte
# ```
#
# Esto genera errores al realizar comparaciones o cálculos.
#
# Pandas permite convertir valores utilizando:
#
# ```python
# pd.to_numeric()
# ```
#
# Los valores inválidos pueden convertirse automáticamente en `NaN`.

# %%
df['edad'].unique()
# Out:
# <StringArray>
# [       '34.0',        '33.0',        '25.0',        '44.0',        '26.0',
#         '23.0',        '39.0',        '43.0',        '41.0',        '32.0',
#         '38.0',        '17.0',        '19.0',        '20.0',        '40.0',
#         '29.0',        '42.0',        '36.0',        '27.0',           nan,
#         '45.0',        '28.0',        '30.0',        '22.0',        '37.0',
#         '21.0',        '18.0',        '35.0',        '31.0',        '24.0',
#          '5.0',        '16.0', 'desconocida',       '120.0']
# Length: 34, dtype: str

# %%
# Conversión temporal de edad a numérico
edad_numerica = pd.to_numeric(df['edad'],errors='coerce')

# Comparar valor original vs convertido
comparacion_edades = pd.DataFrame({'edad_original': df['edad'], 'edad_convertida': edad_numerica})

# Mostrar filas donde hubo problemas de conversión
comparacion_edades[comparacion_edades['edad_convertida'].isna()]
# Out:
#     edad_original  edad_convertida
# 28            NaN              NaN
# 68            NaN              NaN
# 91            NaN              NaN
# 102           NaN              NaN
# 118           NaN              NaN
# 143           NaN              NaN
# 149           NaN              NaN
# 191   desconocida              NaN
# 197           NaN              NaN
# 216           NaN              NaN
# 230           NaN              NaN
# 271           NaN              NaN
# 293           NaN              NaN
# 296           NaN              NaN
# 361           NaN              NaN
# 373           NaN              NaN
# 375           NaN              NaN
# 384           NaN              NaN
# 409           NaN              NaN
# 415           NaN              NaN
# 445           NaN              NaN
# 468           NaN              NaN
# 469           NaN              NaN
# 471           NaN              NaN
# 484           NaN              NaN
# 491           NaN              NaN
# ...

# %%
df['edad'].isnull().sum()
# Out:
# np.int64(26)

# %%
edad_numerica.unique()
# Out:
# array([ 34.,  33.,  25.,  44.,  26.,  23.,  39.,  43.,  41.,  32.,  38.,
#         17.,  19.,  20.,  40.,  29.,  42.,  36.,  27.,  nan,  45.,  28.,
#         30.,  22.,  37.,  21.,  18.,  35.,  31.,  24.,   5.,  16., 120.])

# %%
edad_numerica.isnull().sum()
# Out:
# np.int64(27)

# %%
semestre_num = pd.to_numeric(
    df['semestre'],
    errors='coerce'
)

creditos_num = pd.to_numeric(
    df['creditos_aprobados'],
    errors='coerce'
)

# %%
df['semestre'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Conteo de valores únicos
#
# La función `value_counts()` permite identificar frecuencias de valores.

# %%
df['ciudad'].value_counts()
# Out:
# ciudad
# Bogota          68
# Barranquilla    65
# Bucaramanga     64
# Cali            64
# bogota          63
#  Medellín       62
# BOGOTA          62
# Bogotá          52
#  Bogotá         10
# Name: count, dtype: int64

# %% [markdown]
# # Valores únicos
#
# La función `unique()` permite identificar categorías diferentes dentro de una columna.

# %%
df['ciudad'].unique()

# %%
df['edad'].unique()

# %%
# Revisar valores únicos
print(df['edad'].unique())

# Revisar tipos
print(df['edad'].dtype)

# Revisar valores nulos
print(df['edad'].isna().sum())

# %% [markdown]
# # Ejercicio guiado
#
# Responder:
#
# - ¿Cuántos registros existen?
# - ¿Cuántas columnas tiene el dataset?
# - ¿Qué variables son numéricas?
# - ¿Qué variables son categóricas?
# - ¿Existen inconsistencias visibles?
# - ¿Qué ciudades aparecen registradas?

# %% [markdown]
# # Hallazgos iniciales
#
# Durante la exploración inicial pueden identificarse:
#
# - valores nulos
# - formatos incorrectos
# - inconsistencias de texto
# - duplicados
# - outliers
# - errores tipográficos
#
# La exploración es una etapa crítica antes de iniciar procesos de limpieza.

# %% [markdown]
# # Conclusión del módulo
#
# La exploración de datos permite comprender:
#
# - estructura del dataset
# - calidad de la información
# - posibles problemas
# - estrategias de limpieza
#
# Pandas facilita enormemente el análisis y manipulación de información tabular.

# %% [markdown]
# # Módulo 3 — Calidad de datos y detección de problemas

# %% [markdown]
# ## Objetivos del módulo
#
# Al finalizar este módulo el participante podrá:
#
# - identificar problemas de calidad de datos
# - detectar valores nulos
# - encontrar registros duplicados
# - identificar inconsistencias
# - detectar tipos incorrectos
# - reconocer outliers
# - analizar calidad general del dataset

# %% [markdown]
# # ¿Qué es calidad de datos?
#
# La calidad de datos hace referencia al nivel de:
#
# - precisión
# - consistencia
# - integridad
# - confiabilidad
# - validez
#
# de un conjunto de datos.
#
# ---
#
# ## Problemas más comunes
#
# | Problema | Ejemplo |
# |---|---|
# | Nulos | edad = NaN |
# | Duplicados | mismo registro repetido |
# | Inconsistencias | Bogotá / bogota |
# | Tipos incorrectos | promedio = cuatro |
# | Outliers | edad = 120 |

# %% [markdown]
# # Validación inicial del dataset
#
# Antes de limpiar datos es necesario:
#
# - entender la estructura
# - identificar errores
# - detectar anomalías
# - medir calidad del dataset

# %%
df.head()

# %% [markdown]
# # Valores nulos
#
# Los valores nulos representan información faltante o no registrada.

# %%
df.isnull().sum()

# %% [markdown]
# # Porcentaje de valores nulos
#
# Es importante medir qué porcentaje del dataset presenta datos faltantes.

# %%
(
    df.isnull().sum() / len(df)
) * 100

# %% [markdown]
# # Visualización de valores faltantes
#
# Las columnas con mayor cantidad de nulos pueden requerir:
#
# - imputación
# - eliminación
# - transformación

# %%
df.isnull().sum().sort_values(
    ascending=False
)

# %% [markdown]
# # Detección de duplicados
#
# Los duplicados generan:
#
# - análisis incorrectos
# - sesgos
# - conteos erróneos

# %%
df.duplicated().sum()

# %% [markdown]
# # Visualización de registros duplicados

# %%
df["edad"].duplicated()

# %% [markdown]
# # Inconsistencias de texto
#
# Los datasets reales suelen contener:
#
# ```text
# Bogotá
# bogota
# BOGOTA
# Bogota
# ```
#
# Esto afecta agrupaciones y análisis.

# %%
df['ciudad'].unique()

# %% [markdown]
# # Frecuencia de ciudades registradas

# %%
df['ciudad'].value_counts()

# %% [markdown]
# # Tipos de datos incorrectos
#
# Es común encontrar columnas numéricas almacenadas como texto.

# %%
df.dtypes

# %% [markdown]
# # Conversión de variables numéricas
#
# Convertiremos la columna edad a formato numérico para detectar errores.

# %%
edad_numerica = pd.to_numeric(
    df['edad'],
    errors='coerce'
)

edad_numerica.head()

# %% [markdown]
# # Registros con edades inválidas

# %%
df[edad_numerica.isnull()][
    ['nombre_estudiante', 'edad']
]

# %% [markdown]
# # Detección de outliers
#
# Los outliers son valores extremos o poco realistas.

# %%
edad_numerica.describe()

# %% [markdown]
# # Identificación de edades atípicas

# %%
df[edad_numerica > 90]

# %% [markdown]
# # Análisis de categorías
#
# Es importante validar:
#
# - consistencia
# - frecuencia
# - errores tipográficos

# %%
df['estado_solicitud'].value_counts()

# %% [markdown]
# # Ejercicio guiado
#
# Responder:
#
# - ¿Qué columnas tienen más nulos?
# - ¿Existen duplicados?
# - ¿Qué ciudades presentan inconsistencias?
# - ¿Qué edades parecen inválidas?
# - ¿Qué columnas requieren limpieza?

# %% [markdown]
# # Hallazgos encontrados
#
# Durante el análisis de calidad se identificaron:
#
# - valores faltantes
# - tipos incorrectos
# - registros duplicados
# - inconsistencias textuales
# - posibles outliers
#
# Esto confirma la necesidad de realizar procesos de limpieza y transformación.

# %% [markdown]
# # Conclusión del módulo
#
# La detección temprana de problemas permite:
#
# - prevenir errores analíticos
# - mejorar la calidad del dataset
# - construir procesos reproducibles
# - aumentar confiabilidad de resultados
#
# La calidad de datos es una etapa fundamental dentro de cualquier flujo ETL.

# %% [markdown]
# # Módulo 4 — Limpieza y transformación de datos

# %% [markdown]
# ## Objetivos del módulo
#
# En este módulo aprenderemos a:
#
# - limpiar valores nulos
# - corregir inconsistencias
# - transformar tipos de datos
# - normalizar texto
# - eliminar duplicados
# - preparar datasets para análisis
#
# ---
#
# # Flujo de limpieza
#
# ```text
# Dataset sucio
# ↓
# Detección de errores
# ↓
# Corrección y transformación
# ↓
# Dataset limpio
# ```

# %% [markdown]
# # Limpieza de valores nulos
#
# Los valores faltantes pueden:
#
# - afectar cálculos
# - generar errores
# - producir análisis incorrectos
#
# Las estrategias más comunes son:
#
# - eliminar registros
# - reemplazar valores
# - imputar datos

# %%
# Cantidad de valores nulos

df.isnull().sum()

# %%
# Reemplazo de edades inválidas por NaN

df['edad'] = pd.to_numeric(
    df['edad'],
    errors='coerce'
)

# Imputación usando la mediana

mediana_edad = df['edad'].median()

df['edad'] = df['edad'].fillna(
    mediana_edad
)

df['edad'].head()

# %% [markdown]
# # Normalización de texto
#
# Los datos categóricos suelen presentar inconsistencias:
#
# ```text
# Bogotá
# bogota
# BOGOTA
# Bogota
# ```
#
# Esto afecta agrupaciones y análisis.

# %%
# ============================================
# NORMALIZACIÓN AVANZADA DE TEXTO
# ============================================

# Importamos la librería unicodedata
# Esta librería permite trabajar con caracteres Unicode
# y eliminar tildes o caracteres especiales.

import unicodedata


# ============================================
# FUNCIÓN DE LIMPIEZA DE TEXTO
# ============================================

def limpiar_texto(texto):
    
    # Validamos si el valor es nulo
    # Si es nulo, lo retornamos sin modificar
    
    if pd.isnull(texto):
        return texto
    
    
    # Convertimos el valor a string
    # Esto evita errores si existen datos numéricos
    
    texto = str(texto)
    
    
    # ============================================
    # ELIMINACIÓN DE TILDES
    # ============================================
    
    # normalize('NFKD') separa caracteres especiales
    # Ejemplo:
    # Bogotá -> Bogota + tilde separada
    
    texto = unicodedata.normalize(
        'NFKD',
        texto
    )
    
    
    # encode('ascii', 'ignore')
    # elimina caracteres especiales y tildes
    
    texto = texto.encode(
        'ascii',
        'ignore'
    )
    
    
    # decode('utf-8')
    # convierte nuevamente el texto a formato legible
    
    texto = texto.decode(
        'utf-8'
    )
    
    
    # ============================================
    # NORMALIZACIÓN DE FORMATO
    # ============================================
    
    texto = (
        texto
        
        # Convertir todo a minúsculas
        .lower()
        
        # Eliminar espacios al inicio y final
        .strip()
        
        # Capitalizar correctamente
        .title()
    )
    
    
    # Retornar texto limpio
    
    return texto


# ============================================
# APLICAR LIMPIEZA A LA COLUMNA
# ============================================

df['ciudad'] = df['ciudad'].apply(
    limpiar_texto
)


# ============================================
# VALIDAR RESULTADOS
# ============================================

# Mostramos los valores únicos de la columna
# para verificar que ya no existan duplicados
# por tildes o mayúsculas

df['ciudad'].unique()

# %% [markdown]
# # Eliminación de duplicados
#
# Los duplicados generan:
#
# - sobreconteos
# - sesgos
# - inconsistencias analíticas

# %%
# Duplicados antes de limpiar

df.duplicated().sum()

# Eliminación

df = df.drop_duplicates()

# Duplicados después de limpiar

df.duplicated().sum()

# %% [markdown]
# # Transformación de variables
#
# Es importante garantizar que cada columna tenga el tipo correcto:
#
# | Variable | Tipo esperado |
# |---|---|
# | edad | numérico |
# | promedio | decimal |
# | ciudad | texto |

# %%
# Conversión de promedio

df['promedio'] = pd.to_numeric(
    df['promedio'],
    errors='coerce'
)

df.dtypes

# %% [markdown]
# # Tratamiento de outliers
#
# Los outliers son valores extremos que pueden afectar:
#
# - estadísticas
# - modelos
# - visualizaciones

# %%
# Identificación de edades atípicas

df[df['edad'] > 90]

# %%
# Filtrado de edades válidas

#df = df[df['edad'] <= 90]

#df.shape

# %% [markdown]
# # Validación final del dataset
#
# Después del proceso de limpieza debemos validar:
#
# - tipos de datos
# - valores nulos
# - duplicados
# - consistencia general

# %%
df.info()

df.isnull().sum()

df.duplicated().sum()

# %% [markdown]
# # Ejercicio guiado
#
# Realice las siguientes actividades:
#
# 1. Identifique columnas con valores nulos
# 2. Normalice otra columna textual
# 3. Detecte registros duplicados
# 4. Filtre valores atípicos
# 5. Valide nuevamente el dataset

# %% [markdown]
# # Conclusión del módulo
#
# La limpieza de datos es una etapa fundamental dentro de cualquier flujo ETL.
#
# Un dataset limpio permite:
#
# - análisis confiables
# - visualizaciones correctas
# - modelos consistentes
# - automatización de procesos
#
# La calidad de los resultados depende directamente de la calidad de los datos.

# %% [markdown]
# # Módulo 5 — Visualización y análisis exploratorio de datos

# %%
# Instalar librerías de visualización
# Ejecutar solo si seaborn no está instalado

# !pip install seaborn matplotlib

# %% [markdown]
# ## Objetivos del módulo
#
# En este módulo aprenderemos a:
#
# - visualizar datos
# - interpretar distribuciones
# - detectar patrones
# - identificar outliers
# - analizar relaciones entre variables
# - realizar análisis exploratorio (EDA)
#
# ---
#
# # ¿Qué es EDA?
#
# EDA significa:
#
# ```text
# Exploratory Data Analysis
# ```
#
# Es el proceso de explorar y comprender los datos antes de modelar o automatizar procesos.
#
# El análisis exploratorio permite:
#
# - detectar errores
# - encontrar patrones
# - validar hipótesis
# - identificar anomalías
# - comprender el comportamiento del dataset

# %% [markdown]
# # Librerías de visualización
#
# ## Matplotlib
#
# Es la librería base de visualización en Python.
#
# Permite:
#
# - crear gráficos
# - personalizar visualizaciones
# - generar dashboards básicos
#
# ---
#
# ## Seaborn
#
# Seaborn está construido sobre Matplotlib y facilita:
#
# - visualizaciones estadísticas
# - gráficos más estéticos
# - análisis exploratorio rápido
#
# ---
#
# # Implicaciones del uso de visualización
#
# La visualización permite:
#
# - detectar errores invisibles en tablas
# - encontrar outliers rápidamente
# - validar distribuciones
# - apoyar toma de decisiones
#
# Sin visualización, muchos problemas de datos pasan desapercibidos.

# %%
# ============================================
# IMPORTACIÓN DE LIBRERÍAS
# ============================================

import matplotlib.pyplot as plt
import seaborn as sns


# ============================================
# CONFIGURACIÓN VISUAL
# ============================================
# Configurar estilo visual
sns.set_style("whitegrid")

# Crear figura y definir tamaño
plt.figure(figsize=(10, 5))

# ============================================
# GRÁFICO DE EJEMPLO
# ============================================

# Histograma de edades
sns.histplot(df['edad'], bins=50, kde=True)

# Título del gráfico
plt.title('Distribución de edades')

# Etiquetas de ejes
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Mostrar gráfico
plt.show()

# %% [markdown]
# La función figsize permite controlar el ancho y alto de la visualización en pulgadas, facilitando la adaptación de los gráficos para análisis exploratorios, reportes y dashboards.

# %% [markdown]
# # Distribución de edades
#
# El histograma permite analizar:
#
# - distribución
# - concentración
# - dispersión
# - posibles outliers
#
# ---
#
# # ¿Qué observaremos?
#
# - edades más frecuentes
# - presencia de valores extremos
# - comportamiento general de la variable

# %%
# ============================================
# HISTOGRAMA DE EDADES
# ============================================

# Configurar estilo visual
sns.set_style("whitegrid")
plt.figure(figsize=(10, 5))

sns.histplot(
    df['edad'],
    bins=20,
    kde=True
)

plt.title(
    'Distribución de edades'
)

plt.xlabel('Edad')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# # Interpretación del histograma
#
# El histograma permite identificar:
#
# - concentración de registros
# - distribución normal o sesgada
# - valores extremos
# - comportamiento general de la variable
#
# ---
#
# # Posibles hallazgos
#
# - edades concentradas entre 20 y 40 años
# - presencia de valores atípicos
# - sesgo hacia ciertos rangos

# %% [markdown]
# # Boxplot — detección de outliers
#
# El boxplot es una de las herramientas más utilizadas en análisis exploratorio.
#
# Permite detectar:
#
# - outliers
# - dispersión
# - mediana
# - rango intercuartílico

# %%
# ============================================
# BOXPLOT DE EDADES
# ============================================
# Configurar estilo visual
sns.set_style("whitegrid")
plt.figure(figsize=(10, 4))

sns.boxplot(
    x=df['edad']
)

plt.title(
    'Detección de outliers en edades'
)

plt.show()

# %% [markdown]
# # Interpretación del boxplot
#
# ## Elementos importantes
#
# | Elemento | Significado |
# |---|---|
# | Línea central | mediana |
# | Caja | rango intercuartílico |
# | Puntos externos | posibles outliers |
#
# ---
#
# # Implicaciones
#
# Los outliers pueden:
#
# - distorsionar promedios
# - afectar modelos
# - generar conclusiones incorrectas

# %% [markdown]
# # Análisis de categorías
#
# Las variables categóricas también pueden visualizarse.

# %%
# ============================================
# FRECUENCIA DE CIUDADES
# ============================================
# Configurar estilo visual
sns.set_style("whitegrid")
plt.figure(figsize=(10, 5))

sns.countplot(
    x='ciudad',
    data=df
)

plt.title(
    'Distribución por ciudad'
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Interpretación del countplot
#
# Este gráfico permite identificar:
#
# - categorías más frecuentes
# - desbalance de datos
# - posibles inconsistencias
#
# ---
#
# # Importancia
#
# Las variables desbalanceadas pueden afectar:
#
# - análisis estadísticos
# - modelos predictivos
# - inferencias

# %% [markdown]
# # Relación entre variables
#
# El análisis exploratorio también permite estudiar relaciones entre variables numéricas.

# %%
# ============================================
# RELACIÓN ENTRE EDAD Y PROMEDIO
# ============================================

plt.figure(figsize=(10, 6))

sns.scatterplot(
    x='edad',
    y='promedio',
    data=df
)

plt.title(
    'Relación entre edad y promedio'
)

plt.show()

# %% [markdown]
# # Interpretación del scatterplot
#
# El scatterplot permite identificar:
#
# - correlaciones
# - agrupamientos
# - tendencias
# - anomalías
#
# ---
#
# # Preguntas importantes
#
# - ¿Existe relación entre edad y promedio?
# - ¿Hay agrupamientos?
# - ¿Existen valores atípicos?

# %% [markdown]
# # Correlación entre variables
#
# La correlación mide la relación entre variables numéricas.
#
# Valores cercanos a:
#
# | Valor | Interpretación |
# |---|---|
# | 1 | relación positiva fuerte |
# | 0 | sin relación |
# | -1 | relación negativa fuerte |

# %%
# ============================================
# MATRIZ DE CORRELACIÓN
# ============================================

correlacion = df[
    ['edad', 'promedio',]
].corr()

correlacion

# %%
# ============================================
# HEATMAP DE CORRELACIÓN
# ============================================

plt.figure(figsize=(6, 4))

sns.heatmap(
    correlacion,
    annot=True,
    cmap='Blues'
)

plt.title(
    'Mapa de correlación'
)

plt.show()

# %% [markdown]
# # Implicaciones del análisis exploratorio
#
# El EDA permite:
#
# - comprender mejor el dataset
# - detectar problemas ocultos
# - mejorar calidad de datos
# - apoyar decisiones analíticas
# - preparar información para Machine Learning
#
# ---
#
# # En proyectos reales
#
# EDA es una etapa obligatoria dentro de:
#
# - Data Engineering
# - Data Science
# - Business Intelligence
# - Machine Learning

# %% [markdown]
# # Ejercicio guiado
#
# Realice las siguientes actividades:
#
# 1. Crear un histograma de otra variable
# 2. Identificar posibles outliers
# 3. Crear un gráfico categórico adicional
# 4. Interpretar tendencias observadas
# 5. Analizar posibles relaciones entre variables

# %% [markdown]
# # Conclusión del módulo
#
# La visualización de datos transforma información tabular en conocimiento interpretable.
#
# Las herramientas gráficas permiten:
#
# - identificar patrones
# - detectar anomalías
# - validar calidad de datos
# - apoyar decisiones
#
# EDA es una de las etapas más importantes dentro del análisis de datos moderno.

# %% [markdown]
# # Módulo 6 — Automatización y construcción de pipelines ETL

# %% [markdown]
# ## Objetivos del módulo
#
# En este módulo aprenderemos a:
#
# - automatizar procesos de limpieza
# - construir funciones reutilizables
# - implementar pipelines ETL
# - validar calidad automáticamente
# - exportar datasets procesados
# - construir flujos reproducibles
#
# ---
#
# # ¿Por qué automatizar?
#
# En proyectos reales los datasets:
#
# - cambian constantemente
# - aumentan de tamaño
# - llegan desde múltiples fuentes
# - requieren procesamiento repetitivo
#
# Por esta razón no es viable limpiar datos manualmente.
#
# La automatización permite:
#
# - reproducibilidad
# - escalabilidad
# - reducción de errores
# - eficiencia operativa

# %% [markdown]
# # Concepto de pipeline ETL
#
# Un pipeline ETL automatiza:
#
# ```text
# Extract  →  Transform  →  Load
# ```
#
# ---
#
# # Extract
#
# Obtención de datos desde:
#
# - CSV
# - Excel
# - APIs
# - bases de datos
# - servicios externos
#
# ---
#
# # Transform
#
# Etapa de limpieza y procesamiento:
#
# - normalización
# - eliminación de errores
# - transformación de variables
# - validaciones
# - enriquecimiento
#
# ---
#
# # Load
#
# Carga de datos hacia:
#
# - archivos procesados
# - bases de datos
# - dashboards
# - modelos analíticos

# %% [markdown]
# # Arquitectura del pipeline del taller
#
# ```text
# Dataset crudo
#         ↓
# Lectura con Pandas
#         ↓
# Validación inicial
#         ↓
# Limpieza y transformación
#         ↓
# Normalización
#         ↓
# Validación final
#         ↓
# Exportación
#         ↓
# Dataset limpio
# ```
#
# ---
#
# # Características del pipeline
#
# - reproducible
# - modular
# - reutilizable
# - escalable
# - automatizable

# %%
# ============================================
# IMPORTACIÓN DE LIBRERÍAS
# ============================================

import pandas as pd
import numpy as np
import unicodedata

# %% [markdown]
# # Construcción de funciones reutilizables
#
# En ingeniería de datos se evita repetir código.
#
# Las funciones permiten:
#
# - reutilización
# - mantenimiento sencillo
# - modularidad
# - automatización
# - escalabilidad

# %%
# ============================================
# FUNCIÓN DE NORMALIZACIÓN DE TEXTO
# ============================================

def limpiar_texto(texto):
    
    # Validar valores nulos
    
    if pd.isnull(texto):
        return texto
    
    
    # Convertir a string
    
    texto = str(texto)
    
    
    # Eliminar tildes
    
    texto = unicodedata.normalize(
        'NFKD',
        texto
    ).encode(
        'ascii',
        'ignore'
    ).decode(
        'utf-8'
    )
    
    
    # Normalización general
    
    texto = (
        texto
        .lower()
        .strip()
        .title()
    )
    
    
    return texto

# %% [markdown]
# # Automatización de limpieza
#
# Ahora construiremos una función que procese automáticamente el dataset completo.
#
# ---
#
# # Objetivos
#
# La función realizará:
#
# - conversión de tipos
# - imputación de nulos
# - normalización textual
# - eliminación de duplicados
# - validaciones básicas

# %%
# ============================================
# FUNCIÓN PRINCIPAL DEL PIPELINE
# ============================================

def limpiar_dataset(df):
    
    # Copia de seguridad
    
    df = df.copy()
    
    
    # ============================================
    # LIMPIEZA DE EDAD
    # ============================================
    
    df['edad'] = pd.to_numeric(
        df['edad'],
        errors='coerce'
    )
    
    
    # Imputación usando mediana
    
    mediana_edad = df['edad'].median()
    
    df['edad'] = df['edad'].fillna(
        mediana_edad
    )
    
    
    # ============================================
    # LIMPIEZA DE PROMEDIO
    # ============================================
    
    df['promedio'] = pd.to_numeric(
        df['promedio'],
        errors='coerce'
    )
    
    
    promedio_mediana = df['promedio'].median()
    
    df['promedio'] = df['promedio'].fillna(
        promedio_mediana
    )
    
    
    # ============================================
    # NORMALIZACIÓN DE CIUDAD
    # ============================================
    
    df['ciudad'] = df['ciudad'].apply(
        limpiar_texto
    )
    
    
    # ============================================
    # ELIMINACIÓN DE DUPLICADOS
    # ============================================
    
    df = df.drop_duplicates()
    
    
    # ============================================
    # FILTRADO DE OUTLIERS
    # ============================================
    
    df = df[
        (df['edad'] >= 15) &
        (df['edad'] <= 90)
    ]
    
    
    return df

# %% [markdown]
# # Ejecución del pipeline
#
# Ahora ejecutaremos el proceso automatizado sobre el dataset.

# %%
# ============================================
# EJECUCIÓN DEL PIPELINE
# ============================================

df_limpio = limpiar_dataset(df)

df_limpio.head()

# %% [markdown]
# # Validación posterior al procesamiento
#
# Después de ejecutar el pipeline debemos verificar:
#
# - tipos de datos
# - valores nulos
# - duplicados
# - dimensiones del dataset

# %%
# ============================================
# VALIDACIONES
# ============================================

print("Dimensiones:")
print(df_limpio.shape)

print("\n")

print("Tipos de datos:")
print(df_limpio.dtypes)

print("\n")

print("Valores nulos:")
print(df_limpio.isnull().sum())

print("\n")

print("Duplicados:")
print(df_limpio.duplicated().sum())

# %% [markdown]
# # Implicaciones de la automatización
#
# La automatización permite:
#
# - reducción de tiempo
# - procesamiento masivo
# - trazabilidad
# - reproducibilidad
# - estandarización
#
# ---
#
# # En proyectos reales
#
# Los pipelines ETL son utilizados en:
#
# - Data Warehouses
# - Big Data
# - Machine Learning
# - Business Intelligence
# - Analítica avanzada

# %% [markdown]
# # Exportación de datos
#
# Una vez procesado el dataset es necesario almacenarlo para:
#
# - análisis posteriores
# - dashboards
# - modelos predictivos
# - auditoría
# - integración con otros sistemas

# %%
# ============================================
# EXPORTACIÓN CSV
# ============================================

df_limpio.to_csv(
    '../outputs/dataset_limpio.csv',
    index=False
)

print(
    "Dataset exportado correctamente."
)

# %% [markdown]
# # Exportación a Excel
#
# Muchos procesos empresariales requieren formatos compatibles con herramientas ofimáticas.

# %%
# ============================================
# EXPORTACIÓN EXCEL
# ============================================

df_limpio.to_excel(
    '../outputs/dataset_limpio.xlsx',
    index=False
)

print(
    "Archivo Excel exportado correctamente."
)

# %% [markdown]
# # Trazabilidad y reproducibilidad
#
# Uno de los principios más importantes en ingeniería de datos es la reproducibilidad.
#
# Un proceso reproducible garantiza que:
#
# - el mismo input produce el mismo output
# - los resultados son auditables
# - el pipeline puede escalarse
# - otros equipos pueden reutilizar el flujo

# %% [markdown]
# # Buenas prácticas en pipelines ETL
#
# ## Recomendaciones
#
# - modularizar código
# - validar datos constantemente
# - evitar transformaciones manuales
# - documentar procesos
# - controlar versiones con Git
# - automatizar exportaciones
#
# ---
#
# # Riesgos de no automatizar
#
# - errores humanos
# - inconsistencias
# - baja escalabilidad
# - procesos irreproducibles

# %% [markdown]
# # Ejercicio guiado
#
# Desarrollar un pipeline adicional que:
#
# 1. procese otra columna categórica
# 2. elimine nuevos outliers
# 3. genere métricas automáticas
# 4. exporte resultados
# 5. valide calidad final

# %% [markdown]
# # Caso de aplicación real
#
# Este tipo de pipelines se utiliza en:
#
# - universidades
# - entidades financieras
# - sistemas hospitalarios
# - plataformas de e-commerce
# - sistemas de investigación
# - plataformas gubernamentales
#
# ---
#
# # Ejemplos reales
#
# - procesamiento de matrículas
# - análisis de estudiantes
# - validación de formularios
# - consolidación académica
# - integración de sistemas

# %% [markdown]
# # Conclusión del módulo
#
# La automatización transforma procesos manuales en flujos reproducibles y escalables.
#
# El uso de pipelines ETL permite:
#
# - mejorar calidad de datos
# - reducir errores
# - acelerar procesamiento
# - facilitar auditoría
# - integrar sistemas analíticos
#
# ---
#
# # Resultado del módulo
#
# El participante ahora puede:
#
# - construir pipelines ETL básicos
# - automatizar limpieza
# - validar datasets
# - exportar información procesada
# - desarrollar flujos reproducibles

# %% [markdown]
# # Módulo 7 — Ingeniería de Calidad de Datos y Pipelines Analíticos

# %% [markdown]
# ## Objetivos del módulo
#
# En este módulo integraremos todos los conceptos desarrollados durante el workshop para construir un pipeline profesional de calidad de datos.
#
# ---
#
# # Competencias desarrolladas
#
# Al finalizar este módulo el participante podrá:
#
# - comprender arquitecturas ETL modulares
# - interpretar métricas de calidad de datos
# - aplicar reglas de validación empresarial
# - analizar trade-offs entre calidad y completitud
# - construir pipelines reproducibles
# - evaluar críticamente resultados analíticos
#
# ---
#
# # Contexto
#
# En entornos reales los datasets:
#
# - contienen errores
# - presentan inconsistencias
# - provienen de múltiples fuentes
# - requieren validaciones complejas
#
# Por esta razón, los procesos modernos de ingeniería de datos deben incluir:
#
# - validación
# - gobernanza
# - trazabilidad
# - métricas de calidad
# - automatización

# %% [markdown]
# # Evolución del workshop
#
# Durante el desarrollo del taller evolucionamos progresivamente desde limpieza básica hacia ingeniería de calidad de datos.
#
# ---
#
# # Evolución conceptual
#
# | Etapa | Objetivo |
# |---|---|
# | Exploración inicial | comprender dataset |
# | Limpieza básica | corregir errores simples |
# | Transformación | normalizar variables |
# | EDA | identificar patrones |
# | Automatización | construir pipelines |
# | Validación empresarial | aplicar reglas de negocio |
# | Métricas de calidad | cuantificar resultados |
#
# ---
#
# # Resultado
#
# El workshop evolucionó desde:
#
# ```text
# análisis exploratorio básico
# ```
#
# hacia:
#
# ```text
# arquitectura profesional de calidad de datos
# ```

# %% [markdown]
# # Arquitectura modular implementada
#
# El pipeline fue dividido en componentes especializados para mejorar:
#
# - mantenibilidad
# - reutilización
# - escalabilidad
# - trazabilidad
#
# ---
#
# # Arquitectura final
#
# ```text
# src/
# │
# ├── validators.py
# ├── metrics.py
# ├── cleaning.py
# └── etl_pipeline.py
# ```
#
# ---
#
# # Responsabilidad de cada componente
#
# | Archivo | Función |
# |---|---|
# | validators.py | reglas de validación |
# | metrics.py | métricas de calidad |
# | cleaning.py | orquestación de limpieza |
# | etl_pipeline.py | automatización ETL |

# %% [markdown]
# # Principio de separación de responsabilidades
#
# Uno de los principios fundamentales de ingeniería de software y Data Engineering es:
#
# ```text
# cada componente debe tener una única responsabilidad
# ```
#
# ---
#
# # Ejemplo aplicado
#
# ## validators.py
#
# Responsable únicamente de:
#
# - validar emails
# - validar teléfonos
# - homologar categorías
# - validar fechas
#
# ---
#
# ## cleaning.py
#
# Responsable únicamente de:
#
# - coordinar el flujo de limpieza
# - aplicar transformaciones
# - ejecutar reglas definidas
#
# ---
#
# # Beneficios
#
# - código reutilizable
# - mantenimiento más sencillo
# - reducción de errores
# - mayor escalabilidad

# %% [markdown]
# # Pipeline ETL implementado
#
# El flujo construido sigue la arquitectura clásica ETL:
#
# ```text
# Extract → Transform → Load
# ```
#
# ---
#
# # Extract
#
# Obtención de información desde:
#
# - archivos CSV
# - fuentes heterogéneas
# - datasets parcialmente corruptos
#
# ---
#
# # Transform
#
# Aplicación de:
#
# - validaciones
# - limpieza
# - homologación
# - normalización
# - tratamiento de outliers
#
# ---
#
# # Load
#
# Exportación hacia:
#
# - datasets limpios
# - archivos CSV
# - archivos Excel
# - sistemas analíticos

# %% [markdown]
# # Validaciones empresariales implementadas
#
# El pipeline incorporó reglas de negocio similares a las utilizadas en entornos reales.
#
# ---
#
# # Validaciones implementadas
#
# | Validación | Regla |
# |---|---|
# | Edad | 15 ≤ edad ≤ 90 |
# | Promedio | 0 ≤ promedio ≤ 5 |
# | Créditos | 0 ≤ créditos ≤ 180 |
# | Ingresos | ingresos ≤ 50 millones |
# | Correos | estructura válida |
# | Teléfonos | solo numéricos |
# | Fechas | formato datetime |
#
# ---
#
# # Objetivo
#
# Garantizar que el dataset cumpla criterios mínimos de calidad.

# %% [markdown]
# # Calidad vs completitud
#
# Uno de los hallazgos más importantes del pipeline fue:
#
# ```text
# la calidad y la completitud no siempre aumentan simultáneamente
# ```
#
# ---
#
# # Ejemplo
#
# Antes de validar:
#
# | Campo | Valor |
# |---|---|
# | correo | correo_invalido |
#
# El dataset tenía mayor completitud.
#
# ---
#
# # Después de validar
#
# El pipeline transformó el valor en:
#
# ```text
# NaN
# ```
#
# porque no cumplía las reglas definidas.
#
# ---
#
# # Reflexión importante
#
# En ingeniería de datos:
#
# ```text
# mantener información incorrecta puede ser más peligroso que trabajar con valores faltantes
# ```

# %% [markdown]
# # Trade-offs en calidad de datos
#
# Durante el proceso de limpieza surgieron decisiones importantes.
#
# ---
#
# # Ejemplos de trade-offs
#
# | Estrategia | Beneficio | Riesgo |
# |---|---|---|
# | Conservar datos inválidos | mayor completitud | análisis incorrecto |
# | Invalidar datos | mayor calidad | pérdida de información |
# | Imputar valores | continuidad analítica | introducir sesgo |
# | Eliminar registros | mayor consistencia | reducción del dataset |
#
# ---
#
# # Conclusión
#
# La limpieza de datos implica:
#
# - decisiones técnicas
# - reglas de negocio
# - criterios analíticos
# - evaluación contextual

# %% [markdown]
# # Métricas de calidad de datos
#
# El pipeline incorporó métricas cuantitativas para evaluar la calidad del dataset.
#
# ---
#
# # Métricas utilizadas
#
# | Métrica | Objetivo |
# |---|---|
# | completitud | medir valores presentes |
# | duplicados | detectar redundancia |
# | score de calidad | evaluación global |
# | porcentaje de nulos | evaluar pérdida de información |
#
# ---
#
# # Importancia
#
# Las métricas permiten:
#
# - auditar pipelines
# - comparar resultados
# - medir mejoras
# - justificar decisiones

# %%
# ============================================
# EJECUCIÓN DEL PIPELINE PROFESIONAL
# ============================================

# !python ../src/etl_pipeline.py

# %% [markdown]
# # Interpretación de resultados
#
# El pipeline generó métricas before vs after que permiten evaluar el impacto del saneamiento aplicado.
#
# ---
#
# # Hallazgos importantes
#
# ## Disminución de completitud
#
# En algunas columnas la completitud disminuyó debido a:
#
# - invalidación de correos incorrectos
# - teléfonos corruptos
# - valores fuera de rango
# - fechas inválidas
#
# ---
#
# # Interpretación correcta
#
# Esto NO significa que el pipeline falló.
#
# Significa que:
#
# ```text
# el sistema detectó información inconsistente y la invalidó para preservar la calidad analítica
# ```

# %% [markdown]
# # Gobernanza de datos
#
# Los pipelines modernos no solo transforman información.
#
# También deben:
#
# - garantizar calidad
# - aplicar reglas
# - documentar procesos
# - generar trazabilidad
# - permitir auditoría
#
# ---
#
# # Conceptos relacionados
#
# - Data Governance
# - Data Quality
# - Data Engineering
# - Data Stewardship
# - Data Reliability

# %% [markdown]
# # Escenarios reales de aplicación
#
# Las arquitecturas desarrolladas en este workshop son utilizadas en:
#
# - universidades
# - sistemas financieros
# - plataformas gubernamentales
# - hospitales
# - e-commerce
# - investigación científica
# - sistemas analíticos empresariales
#
# ---
#
# # Ejemplos reales
#
# - validación de matrículas
# - consolidación académica
# - análisis de estudiantes
# - integración institucional
# - preparación para Machine Learning

# %% [markdown]
# # Reflexión técnica final
#
# La limpieza de datos no consiste únicamente en eliminar errores.
#
# Implica:
#
# - comprender el contexto
# - definir reglas de negocio
# - evaluar impacto analítico
# - construir procesos reproducibles
# - cuantificar calidad
#
# ---
#
# # Idea central del workshop
#
# ```text
# la calidad del análisis depende directamente de la calidad de los datos
# ```

# %% [markdown]
# # Conclusión general del workshop
#
# Durante el desarrollo del taller se construyó progresivamente una arquitectura completa de procesamiento analítico.
#
# ---
#
# # Competencias desarrolladas
#
# El participante ahora puede:
#
# - construir pipelines ETL
# - automatizar procesos de limpieza
# - validar calidad de datos
# - interpretar métricas analíticas
# - desarrollar flujos reproducibles
# - aplicar reglas de negocio
# - construir arquitecturas modulares
#
# ---
#
# # Resultado final
#
# El workshop evolucionó desde:
#
# ```text
# limpieza básica de datos
# ```
#
# hacia:
#
# ```text
# ingeniería profesional de calidad de datos y pipelines analíticos
# ```
